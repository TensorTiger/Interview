# %% [markdown]
# <a href="https://colab.research.google.com/github/TensorTiger/Interview/blob/main/VaaniResearch_Interview.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Generating a Random 2D or 1D Matrix

import numpy as np

mat= np.random.random((2,5))

mat = mat.tolist()

# %%
# @title Print the Matrix
mat
# Out:
# [[0.2852222299757454,
#   0.778328253424337,
#   0.15541473524840133,
#   0.0997380994032736,
#   0.10130771253176551],
#  [0.754592181150917,
#   0.18561074683030254,
#   0.6398641156759256,
#   0.7019995092598412,
#   0.33607023329899366]]

# %%
# @title Convert this matrix to transpose
